# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# %pwd
# Out:
# 'C:\\Users\\SHM\\Anaconda_src\\deeplearning'

# %% [markdown]
# ### 이미지 열기

# %%
path ='dog.jpg'

image_pil = Image.open(path)
image = np.array(image_pil)

# %%
image.shape
# Out:
# (734, 1100, 3)

# %% [markdown]
# ### 이미지 들여다 보기

# %%
image.shape
# Out:
# (734, 1100, 3)

# %%
np.min(image), np.max(image)
# Out:
# (0, 255)

# %% [markdown]
# ### 그래프로 시각화 하기

# %%
plt.hist(image.ravel(), 256, [0,256])
plt.show()

# %% [markdown]
# ### 이미지 보기

# %%
plt.imshow(image)
plt.show()

# %%
path
# Out:
# 'dog.jpg'

# %%
image_pil = Image.open(path).convert("L")
image_bw = np.array(image_pil)

# %%
image_bw.shape
# Out:
# (734, 1100)

# %%
plt.imshow(image_bw, 'gray')
plt.show()

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %%
plt.imshow(image_bw, 'inferno')
plt.show()

# %%
plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 두번째 이미지 열기

# %%
cat_path = 'cat.jpg'

cat_pil = Image.open(cat_path)
cat_image = np.array(cat_pil)

# %%
plt.imshow(cat_image)
plt.show()

# %%
cat_image.shape
# Out:
# (183, 275, 3)

# %%
import cv2

# %%
dog_image = cv2.resize(image, (275, 183))
dog_image.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# Image 합치기

# %%
plt.imshow(dog_image)
plt.imshow(cat_image, alpha=0.5)
plt.show()
