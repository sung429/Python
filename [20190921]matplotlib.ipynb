# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ### 점선 그래프

# %%
data = np.random.randn(50).cumsum()
data
# Out:
# array([-0.30599268, -0.47794828, -0.81730168, -0.03524284,  1.49937366,
#         1.73943686,  1.60203306,  2.2700466 ,  3.58068688,  3.48300971,
#         3.1656206 ,  2.9083607 ,  4.39538516,  3.0179599 ,  2.70902452,
#         2.93213227,  2.03377765,  2.94732082,  3.31760708,  3.63335218,
#         4.48343624,  4.75797123,  2.84563119,  4.45093236,  6.59469731,
#         5.84514754,  5.02076063,  4.79164338,  6.24031147,  7.13698285,
#         7.63753615,  7.58103286,  8.18774167,  8.00173061,  8.50376875,
#         8.88246566,  7.78034755,  8.96192076, 10.17188342,  9.22904689,
#        10.40171495,  9.40646584,  7.10081967,  6.74927341,  6.21627186,
#         6.06375249,  6.64461333,  7.87294934,  8.67097785,  6.06710139])

# %%
plt.plot(data)
plt.show()

# %% [markdown]
# ### 여러그래프 그리기

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.show()

# %% [markdown]
# # Multi Graph 그리기

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
plt.subplot(2,2,1)
plt.plot(data)
plt.subplot(2,2,2)
plt.hist(hist_data,bins=20)
plt.subplot(2,1,2)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# ### 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
plt.plot(data, 'y+')
plt.show()

# %%
plt.plot(data, 'v')

# %% [markdown]
# ### 그래프 사이즈 조절

# %%
plt.figure(figsize=(10,10))
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# ### 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps_post')
plt.legend()
plt.show()

# %% [markdown]
# ### 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Random Graph')
plt.xlabel('Stages')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### 저장하기

# %%
plt.savefig('saved_graph.svg')
